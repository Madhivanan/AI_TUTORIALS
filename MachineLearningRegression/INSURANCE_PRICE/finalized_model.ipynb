# %%
import pickle

# %%
# Load the model, Prepare input data (inside [[ ]]),  Predict
load_model = pickle.load(open("LinearRegression.sav", "rb"))
input_data = [[25, 1, 27.5, 1, 0]]
result = load_model.predict(input_data)
result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[6550.86268636]])

# %%
# Load the model, Prepare input data (inside [[ ]]),  Predict
load_model = pickle.load(open("DecisionTreeRegressor.sav", "rb"))
input_data = [[25, 1, 27.5, 1, 0]]
result = load_model.predict(input_data)
result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([4655.67548636])

# %%
# Load the model, Prepare input data (inside [[ ]]),  Predict
load_model = pickle.load(open("RandomForestRegressor.sav", "rb"))
input_data = [[25, 1, 27.5, 1, 0]]
result = load_model.predict(input_data)
result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([7841.3696918])

# %%
# Load the model, Prepare input data (inside [[ ]]),  Predict
load_model = pickle.load(open("AdaBoostRegressor.sav", "rb"))
input_data = [[25, 1, 27.5, 1, 0]]
result = load_model.predict(input_data)
result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# array([6851.17720327])
